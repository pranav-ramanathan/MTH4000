# %%
import math

n = 12

x = [math.cos(2*i*math.pi/n) for i in range(2*n)]
y = [math.sin(2*i*math.pi/n) for i in range(2*n)]

# %%
from matplotlib import pyplot as plt
plt.plot(x[:10], y[:10:])
plt.gca().axis('equal')
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %%
plt.plot(x[1::3], y[1::3])
plt.gca().axis('equal')
# Out:
# (-0.9526279441628831,
#  0.9526279441628827,
#  -0.9526279441628831,
#  0.9526279441628831)

# %%
plt.plot(x[1::], y[:-1:])
plt.gca().axis('equal')
# Out:
# (-1.1, 1.1, -1.1, 1.1)

# %%
data = [1] * 240
mean_temperatures = []
for i in range(1, 241, 12):
    print(len(data[i - 1:(i+11)]))
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12

# %%
import matplotlib.pyplot as plt

def plotter(l):
    x=range(len(l))
    plt.plot(x, l)
    plt.show()

# %%
plotter([1, 2, 3, 4, 5])

# %%
l=[72, 31, 14, 95, 23]

# %%
def f(l):
    m=[l[i]/(i+1) for i in range(len(l))]
    return max(m)
print(f(l))
# Out:
# 72.0

# %%
def f(l):
    binary=[(l[i]%2)*(2**i) for i in range(len(l))]
    return sum(binary)
print(f(l))
# Out:
# 26

# %%
f=lambda x: max(x)-min(x)
print(f(l))
# Out:
# 81

# %%
from numpy import mean as f
print(f(l))
# Out:
# 47.0

# %%
def mean_temp(data: list) -> float:
    """
    Fri, Sat, Sun, Mon, Tues, Wed, Thur
    0  , 1  , 2  , 3  , 4   , 5  , 6
    """
    tuesday_temps = [data[i] for i in range(4, 4 + 5*7, 7)]
    return sum(data[4:4+ 5*7]) / 5

# %%
test = [0, 0, 0, 0, 1, 0, 0] * 100

# %%
mean_temp(test)
# Out:
# 1.0

# %%
y = lambda x: [sum][x//(x+1)]
print(y(10))
# Out:
# <built-in function sum>

# %%
y = lambda x: dir(x)
y(10)
# Out:
# ['__abs__',
#  '__add__',
#  '__and__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__lshift__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  '__xor__',
# ...

# %%
z = lambda x: (lambda y: 7*y)(x)
z(10)(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 z = lambda x: (lambda y: 7*y)(x)
# ----> 2 z(10)(10)
#
# TypeError: 'int' object is not callable
